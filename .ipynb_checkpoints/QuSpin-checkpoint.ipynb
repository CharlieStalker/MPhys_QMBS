# %%
import numpy as np
from quspin.operators import hamiltonian # Hamiltonians and operators
from quspin.basis import spin_basis_1d # Hilbert space fermion basis
from quspin.tools.block_tools import block_diag_hamiltonian # block diagonalisation
import sys,os
from matplotlib import pyplot as plt
os.environ['KMP_DUPLICATE_LIB_OK']='True' # uncomment this line if omp error occurs on OSX for python 3
os.environ['OMP_NUM_THREADS']='6' # set number of OpenMP threads to run in parallel
os.environ['MKL_NUM_THREADS']='6' # set number of MKL threads to run in parallel
os.environ['MKL_DEBUG_CPU_TYPE'] = '5'
import scienceplots
plt.style.use(['science','ieee'])
plt.rcParams['text.usetex'] = True
from scipy.stats import gaussian_kde
import mpl_scatter_density # adds projection='scatter_density'
from matplotlib.colors import LinearSegmentedColormap

# %%
## Model parameters
L = 16
Ja=-9.3 # /2 Pi 
Je=-6.1
jx = np.random.normal(size = L-3)*np.pi
Omega=3*np.pi
J_nn = 0.3
basis = spin_basis_1d(L,Nup=int(L/2), pauli = 0)
i_0 = basis.index('1001100110011001')

# %%
ja_hop_pm,je_hop_pm,ja_hop_mp,je_hop_mp,omega,j_nn = [],[],[],[],[],[]
for i in range(L-1):
    if i%2 == 0:
        ja_hop_pm+=[[Ja,i,(i+1)]]
        ja_hop_mp+=[[Ja,i,(i+1)]]
    else:
        je_hop_pm+=[[Je,i,(i+1)]]
        je_hop_mp+=[[Je,i,(i+1)]]
#Staircase potential
for n in range(int(L/2)):
    site = 2*n
    omega_val =0.8*n
    omega += [[omega_val,site,site],[omega_val,site-1,site-1]]
    
# next-next-nearest
for i in range(L-3):
    j_nn += [[J_nn,i,i+3]]
#for i in range(L-3):
    #jx_nn += [[jx[i]/2,i,i+2]]

# %%
static = [['+-',ja_hop_pm],['-+',ja_hop_mp],['+-',je_hop_pm],['-+',je_hop_mp],['+-',omega],['+-',j_nn],['-+',j_nn]]
dynamic = []

# %%
S_n, S_nn = [],[]
for i in range(L):
    if (i+1)%4 not in [0,1]:
        S_n += [[1,i]]
    else:
        S_n += [[-1,i]]
static2 = [['z',S_n]]
H_QFI = hamiltonian(static2,dynamic,basis=basis)
# Out:
# Hermiticity check passed!
# Particle conservation check passed!
# C:\Users\Charlie\anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Test for symmetries not implemented for <class 'quspin.basis.basis_1d.spin.spin_basis_1d'>, to turn off this warning set check_symm=False in hamiltonian

# %%
H= hamiltonian(static,dynamic, basis=basis)
# Out:
# Hermiticity check passed!
# Particle conservation check passed!
# C:\Users\Charlie\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Test for symmetries not implemented for <class 'quspin.basis.basis_1d.spin.spin_basis_1d'>, to turn off this warning set check_symm=False in hamiltonian
#   """Entry point for launching an IPython kernel.

# %%
eigenvalues,eigenvectors = H.eigh()

# %%
psi_0 = np.zeros(basis.Ns)
psi_0_thermal = np.zeros(basis.Ns)
psi_0[i_0]=1
psi_0_thermal[600]=1
times = np.linspace(0,50,10000)

# %%
psi_t = H.evolve(psi_0,times.min(),times)
psi_t_thermal = H.evolve(psi_0_thermal,times.min(),times)

# %%
entropies = []
pa_t = []
thermal_entropies = []
for i in range(len(times)):
    entropies.append(basis.ent_entropy(psi_t[:,i],sub_sys_A = [0,1,2,3])['Sent_A'])
    thermal_entropies.append(basis.ent_entropy(psi_t_thermal[:,i],sub_sys_A = [0,1,2,3])['Sent_A'])
    pa_t.append(basis.partial_trace(psi_t[:,i],[0,1,2,3]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27356\92360197.py in <module>
#       3 thermal_entropies = []
#       4 for i in range(len(times)):
# ----> 5     entropies.append(basis.ent_entropy(psi_t[:,i],sub_sys_A = [0,1,2,3])['Sent_A'])
#       6     thermal_entropies.append(basis.ent_entropy(psi_t_thermal[:,i],sub_sys_A = [0,1,2,3])['Sent_A'])
#       7     pa_t.append(basis.partial_trace(psi_t[:,i],[0,1,2,3]))
#
# ~\anaconda3\lib\site-packages\quspin\basis\base.py in ent_entropy(self, state, sub_sys_A, density, subsys_ordering, return_rdm, enforce_pure, return_rdm_EVs, sparse, alpha, sparse_diag, maxiter, svd_solver, svd_kwargs)
#     383                                                                 enforce_pure=enforce_pure,return_rdm_EVs=return_rdm_EVs,
#     384                                                                 sparse=sparse,alpha=alpha,sparse_diag=sparse_diag,maxiter=maxiter,
# --> 385 								svd_solver=svd_solver, svd_kwargs=svd_kwargs )
#     386
#     387         def expanded_form(self,static=[],dynamic=[]):
#
# ~\anaconda3\lib\site-packages\quspin\basis\lattice.py in _ent_entropy(self, state, sub_sys_A, density, subsys_ordering, return_rdm, enforce_pure, return_rdm_EVs, sparse, alpha, sparse_diag, maxiter, svd_solver, svd_kwargs)
#     391                         if state.ndim==1:
#     392                                 state = state.reshape((-1,1))
# --> 393                                 p, rdm_A, rdm_B = self._p_pure(state,sub_sys_A,svd_solver=svd_solver,svd_kwargs=svd_kwargs,return_rdm=return_rdm,compute_signs=compute_signs)
#     394
#     395                         elif state.ndim==2:
#
# ~\anaconda3\lib\site-packages\quspin\basis\lattice.py in _p_pure(self, state, sub_sys_A, svd_solver, svd_kwargs, return_rdm, compute_signs)
#     558
#     559                 # calculate full H-space representation of state
# --> 560                 state=self.project_from(state,sparse=False)
#     561
#     562                 if compute_signs: # imprint fermion signs
#
# ~\anaconda3\lib\site-packages\quspin\basis\basis_1d\base_1d.py in project_from(self, v0, sparse, pcon)
#     716                                 return  _np.squeeze(_get_vec_dense(self._bitops,self._pars,v0,self._basis,norms,ind_neg,ind_pos,shape,C,self._L,**self._blocks_1d))
#     717                         else:
# --> 718                                 return _get_vec_dense(self._bitops,self._pars,v0,self._basis,norms,ind_neg,ind_pos,shape,C,self._L,**self._blocks_1d)
#     719
#     720         def get_proj(self,dtype,pcon=False):
#
# ~\anaconda3\lib\site-packages\quspin\basis\basis_1d\base_1d.py in _get_vec_dense(ops, pars, v0, basis_in, norms, ind_neg, ind_pos, shape, C, L, **blocks)
#    1076         for r in range(0,L//a):
#    1077                 C(r,k,c,norms,dtype,ind_neg,ind_pos)
# -> 1078                 vc = (v0.T*c).T
#    1079                 vc_tran = vc.transpose()
#    1080                 vc_tran *= sign
#
# KeyboardInterrupt:

# %%
plt.plot(times,entropies,label = 'Pi')
plt.plot(times,thermal_entropies,label = 'Thermal')
plt.xlabel('Time')
plt.ylabel(r'$S_a$')
plt.legend()

# %%
#Dynamics of Fidelity
timefidels = []
thermfidels =[]
for i in range(len(times)):
    timefidels.append(np.abs(np.vdot(psi_0,psi_t[:,i])**2))
    thermfidels.append(np.abs(np.vdot(psi_0_thermal,psi_t_thermal[:,i])**2))

# %%
plt.plot(times,timefidels,label='pi')
plt.plot(times,thermfidels,label='thermal')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Fidelity')
# Out:
# Text(0, 0.5, 'Fidelity')

# %%
fidelsoverlap = []
for i in range(len(eigenvectors)):
    fidelsoverlap.append(np.abs(np.vdot(psi_0,eigenvectors[:,i])**2)/L)

# %%
with plt.style.context(['science', 'scatter']):
    plt.scatter(eigenvalues,fidelsoverlap,s=3,c='black')
    plt.yscale('log')
    plt.ylabel('overlap of psi0, eigenvector')
    plt.ylim(bottom = 10**-4,top = 0.0001)
    #plt.xlim(left =-40,right = -35)
    fig=plt.figure()
# Out:
# C:\Users\Charlie\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Attempting to set identical bottom == top == 0.0001 results in singular transformations; automatically expanding.
#   """

# %%
white_viridis = LinearSegmentedColormap.from_list('white_viridis', [
    (0, '#ffffff'),
    (1e-20, '#440053'),
    (0.2, '#404388'),
    (0.4, '#2a788e'),
    (0.6, '#21a784'),
    (0.8, '#78d151'),
    (1, '#fde624'),
], N=256)

def using_mpl_scatter_density(fig, x, y):
    ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
    density = ax.scatter_density(eigenvalues, fidelsoverlap, cmap=white_viridis)
    fig.colorbar(density)

fig = plt.figure()
using_mpl_scatter_density(fig, eigenvalues, fidelsoverlap)
plt.yscale('log')

plt.ylabel(r'$\log_{10}|\langle\psi(0)|E_i\rangle|^2$')
plt.xlabel(r'$E_n$')
plt.tight_layout()
plt.show()

# %%
spacing = []
for i in range(int(0.25*len(eigenvalues)),int(0.75*len(eigenvalues))):
    space = eigenvalues[i+1] - eigenvalues[i]
    #if space != 0:
    spacing.append(space)
S_i = spacing/np.mean(spacing)
Poisson=[]
Wigner_Dyson = []
for i in np.linspace(0,S_i.max()):
    Poisson.append(np.exp(-1*i))
    Wigner_Dyson.append((i*np.pi/2)*np.exp((-np.pi/4)*(i**2)))

# %%
S_i
# Out:
# array([1.66792673, 1.28248698, 1.177084  , ..., 1.177084  , 1.28248698,
#        1.66792673])

# %%
with plt.style.context(['science']):
    P_s,bins= np.histogram(S_i,density=True,bins=50)
    bins_mean = [0.5 * (bins[i] + bins[i+1]) for i in range(len(P_s))]
    plt.scatter(bins_mean,P_s,label = 'Simulated',s=3,color='black')
    plt.plot(np.linspace(0,S_i.max()),Poisson,color='red',label = 'Poisson Distribution',ls='--')
    plt.plot(np.linspace(0,S_i.max()),Wigner_Dyson,color='green',label = 'Wigner-Dyson Distribution')
    plt.legend()

# %%
len(P_s)
# Out:
# 50

# %%
eigen_entropies = []
for i in range(len(eigenvalues)):
    eigen_entropies.append(basis.ent_entropy(eigenvectors[:,i],sub_sys_A = [0,1,2,3])['Sent_A']/L)

# %%
with plt.style.context(['science', 'scatter']):
    plt.title('Bipartite Entanglement Entropy of Eigenstates')
    plt.scatter(eigenvalues/L,eigen_entropies,s=4,color='black')
    plt.xlabel('E')
    plt.ylabel(r'$S_a$')

# %%
test = basis.get_vec(psi_t[:,3])
test
# Out:
# <65536x1 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 12870 stored elements in Compressed Sparse Column format>

# %%
psi_0 * H
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27356\3935761017.py in <module>
# ----> 1 psi_0 * H
#
# ~\anaconda3\lib\site-packages\quspin\operators\hamiltonian_core.py in __array_ufunc__(self, func, method, *inputs, **kwargs)
#    3010                                 return inputs[0].__mul__(inputs[1])
#    3011                         elif ishamiltonian(inputs[1]):
# -> 3012                                 return inputs[1].__rmul__(inputs[0])
#    3013                 elif (func == _np.subtract):
#    3014                         if ishamiltonian(inputs[0]):
#
# ~\anaconda3\lib\site-packages\quspin\operators\hamiltonian_core.py in __rmul__(self, other)
#    2133
#    2134                 elif other.__class__ == _np.ndarray:
# -> 2135                         self._mat_checks(other,casting="unsafe")
#    2136                         return self._rmul_dense(other)
#    2137
#
# ~\anaconda3\lib\site-packages\quspin\operators\hamiltonian_core.py in _mat_checks(self, other, casting)
#    2333                 try:
#    2334                         if other.shape != self._shape: # only accepts square matricies
# -> 2335                                 raise ValueError('shapes do not match')
#    2336                         if not _np.can_cast(other.dtype,self._dtype,casting=casting):
#    2337                                 raise ValueError('cannot cast types')
#
# ValueError: shapes do not match

# %%
psi_t[i_0,0]
# Out:
# (1+0j)

# %%
psi_s=np.zeros(basis.Ns)
# obtain array index for the fock state |01>
array_ind_s=basis.index( basis[1] )
# construct the pure state |01>
psi_s[array_ind_s]=1.0
# Out:
# print state psi_s in the basis:
# [0. 1. 0. ... 0. 0. 0.]

# %%
len(psi_t)
# Out:
# 12870

# %%
eigenvectors[:,3].T.conjugate()@H.dot(eigenvectors[:,1])
# Out:
# (2.5318636076576695e-13+0j)

# %%
def QFI(Psi_i,Psi_j,P_i,P_j, H ):
    QFI = 0 
    for i in range(len(eigenvectors_i)):
        for j in range(len(eigenvectors_i)):
            if i != j:
                QFI += ((P_i-P_j)**2)/(P_i+P_j) * abs(eigenvectors[:,i].T.conjugate()@H.dot(Psi_J[:,j]))**2
    return QFI/2 

def QFI2(Psi_t, H ):
    QFI = 0 
    for i in range(len(psi_t)):
        psi_i=np.zeros(basis.Ns)
        # obtain array index for the fock state |01>
        array_ind_s=basis.index( basis[i] )
        # construct the pure state |01>
        psi_s[array_ind_s]=1.0 
        P_i = Psi_t[i]
        for j in range(len(psi_t)):
            if i != j:
                P_j = Psi_t[j]
                if P_j + P_i !=0:
                    psi_j=np.zeros(basis.Ns)
                    # obtain array index for the fock state |01>
                    array_ind_s=basis.index( basis[j] )
                    # construct the pure state |01>
                    psi_j[array_ind_s]=1.0 
                    QFI += ((P_i-P_j)**2)/(P_i+P_j) * abs(psi_i.T.conjugate()@H.dot(psi_j))**2
    return QFI/2

# %%
H_QFI.quant_fluct(psi_t[:,2])
# Out:
# (0.27420277540041127-4.763247698328114e-17j)

# %%
qfis = []
qfis_t=[]
for i in range(9999):
    qfis.append((4/L)*H_QFI.quant_fluct(psi_t[:,i]))
    qfis_t.append((4/L)*H_QFI.quant_fluct(psi_t_thermal[:,i]))

# %%
plt.plot(qfis, label= 'Pi state')
plt.plot(qfis_t,label= 'Thermal',color='blue',ls = '--')
plt.xlabel(r'$\barP{f _Q}$')
plt.legend()
plt.xscale('log')
